# %% [markdown]
# # Søk i tidsskrift

# %%
import json
import sqlite3
import requests
import pandas as pd
import dhlab.module_update as mu
mu.update('mods_meta')
import mods_meta as mm
import dhlab.nbtext as nb
from dhlab.nbtokenizer import tokenize
import re
from IPython.display import Markdown
from collections import Counter
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\bokhylla_api_medietyper\mods_meta.py`

# %% [markdown]
# ### fjern ellipser i pandarammer

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Hjelpefunksjoner

# %%
def nb_search(
    term = '', 
    creator = None, 
    number = 50, 
    page = 0, 
    title = None,
    mediatype = None, 
    lang = None,
    period = None,
    random = False
):
    """Søk etter term og få ut json"""
    
    # max number of hits pr. page
    # page has also a max of 50 - not checked
    
    number = min(number, 50)
    
    filters = []
    aq = []
    

    params = {
        'page':page, 
        'size':number,
        'random': random
    }
    
    if lang != None:
        aq.append('languages:{lang}'.format(lang = lang ))
    
    if title != None:
        filters.append('title:{title}'.format(title = title))
        
    if creator != None:
        filters.append('creator:{c}'.format(c=creator))
    
    if mediatype != None:
        filters.append('mediatype:{mediatype}'.format(mediatype=mediatype))
    
    if period != None:
        filters.append('date:[{date_from} TO {date_to}]'.format(date_from = period[0], date_to = period[1]))
    
    if filters != []:
        params['filter'] = filters
    
    if aq != []:
        params['aq'] = aq
        
    if term != None:
        params['q'] = term
    
    r = requests.get("https://api.nb.no:443/catalog/v1/items", params = params)
    
    return r.json()

def find_urns_sesam(term = None, creator = None, number=50, page=0, lang = None, title = None, mediatype = None, 
                    period = None, random = False):
    """generates urns/sesamid from item search"""
    x = nb_search(
        term = term, creator = creator, title = title,
        number = number, page = page, mediatype=mediatype, period = period, 
        lang = lang,
        random = random
    )
    try:
        sesamid =[f['id'] for f in x['_embedded']['items']]
    except:
        sesamid = []
    return sesamid


def find_items(term = None, 
               creator = None, 
               number = 100, 
               lang = None, 
               title = None, 
               mediatype = None, 
                period = None
              ):
    """find ids from a spec"""
    pages = number // 50
    lastnumbers = number % 50
    print(pages, lastnumbers)
    res = []
    # fetch ids from pages, max hits
    for page in range(pages):
        x = nb_search(
            term = term, creator = creator, title = title,
            number = 50, page = page, mediatype = mediatype, period = period, 
            lang = lang
        )
        res += [f['id'] for f in x['_embedded']['items']]

    # fetch ids from last page
    x = nb_search(
            term = term, creator = creator, title = title,
            number = lastnumbers, page = pages + 1, mediatype=mediatype, period = period, 
            lang = lang)
    res += [f['id'] for f in x['_embedded']['items']]
                  
    return res

def fetch_keys(m, path, delimiter = "/", res = [], start_list = '#'):
    """path /-delimited string, return res if fails, array indices indicaed with start_list"""
    
    # get the sequence of path elements
    path = path.split(delimiter)
    
    x = m
    try:
        for i in range(0, len(path)):
            if path[i].startswith(start_list):
                # then the item is an array selector
                index = int(path[i].split(start_list)[-1])
                x = x[index]
            else:
                x = x[path[i]]
    except KeyError:
        x = res
    return x
        
def find_item(data, item):
    res = []
    if isinstance(data, list):
        print('list', data)
        for subdata in data:
            res += find_item(subdata, item)
    elif isinstance(data, dict):
        for key in data:
            if item in data[key]:
                print('dictvalue',key, data[key])
                res.append(data[key][item])
            else:
                res += find_item(data[key], item)
    return res

def metadata(id):
    r = requests.get("https://api.nb.no:443/catalog/v1/items/" + str(id))

    d = r.json()
    res = {
        'title': fetch_keys(d, 'metadata/title'),
        'contr':[(fetch_keys(x, 'name'), fetch_keys(x, 'roles/#0/name')) for x in fetch_keys(d, 'metadata/people')],
        'pages': fetch_keys(d, 'metadata/physicalDescription/extent'),
        'urn': fetch_keys(d, 'metadata/identifiers/urn'),
        'year': fetch_keys(d, 'metadata/originInfo/issued'),
        'topics':fetch_keys(d, 'metadata/subject/topics'),
        'genres': fetch_keys(d, 'metadata/genres'),
        'target_group':fetch_keys(d, 'metadata/targetAudienceNotes')
                            
    }

    return res

def get_konks(urn, phrase, window = 500, n = 1000):
    import requests
    querystring = '"'+ phrase +'"' 
    query = {
        'q':querystring,
        'fragments': n,
        'fragSize':window
       
    }
    r = requests.get("https://api.nb.no/catalog/v1/items/{urn}/contentfragments".format(urn=urn), params = query)
    res = r.json()
    results = []
    try:
        for x in res['contentFragments']:
            pid = x['pageid']
            hit = x['text']
            splits = hit.split('<em>')
            s2 = splits[1].split('</em>')
            before = splits[0]
            word = s2[0]
            after = s2[1]
            results.append({'urn': urn, 'before': before, 'word':word, 'after':after})
    except:
        True
    return results

def get_konkordanser(word = '', urns = None, window = 500, n = 1000):
    konks = []
    for u in urns:
        konks += get_konks(u, word, window = window, n = n)
    return konks

# %%
def count_from_conc(concordance):
    """From a concordance, count the words in it. Assume konks reside a dataframe with columns 'after' and 'before'"""
    word = concordance['word'][0]
    return nb.frame_sort(nb.frame(Counter(tokenize(' '.join(concordance['after'].values + concordance['before'].values))), word))

def count_from_conc_window(concordance, before = 5, after = 5):
    """From a concordance, count the words in it. Assume konks reside a dataframe with columns 'after' and 'before'"""
    word = concordance['word'][0]
    # join before and after
    return nb.frame_sort(
            nb.frame(
                Counter(
                    [tokens for toklists in [tokenize(c)[:after] for c in concordance['after'].values] for tokens in toklists] 
                    + 
                    [tokens for toklists in [tokenize(c)[-before:] for c in concordance['before'].values] for tokens in toklists]
                )
            ), 
            word
        )

# %% [markdown]
# # Søk i tidsskrift

# %%
x = nb_search(term='allehånde', mediatype='tidsskrift')

# %%
fetch_keys(x, 'metadata/identifiers/urn')
# Out:
# []

# %%
rand = set()
for i in range(1):
    rand |= set(find_urns_sesam('vi',  number = 50, random = True, mediatype = 'tidsskrift', title = 'blikk'))

# %%
len(rand)
# Out:
# 50

# %%
meta =  {x:metadata(x) for x in rand}
meta
# Out:
# {'7464a037c599594464e3269a70020bc3': {'title': 'Blikk (trykt utg.). 1996 Nr. 1',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181060_001',
#   'year': '1996',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '0bf8a20978e74e3181d536c81d16b80e': {'title': 'Blikk (trykt utg.). 2007 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481106_001',
#   'year': '2007',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '65f6996e57694e86056739ca4bd2d152': {'title': 'Blikk (trykt utg.). 1992 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181035_001',
#   'year': '1992',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '76c9603671eb7406db2c3cdfa7d8a27c': {'title': 'Blikk (trykt utg.). 2007 Nr. 10',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481252_001',
#   'year': '2007',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '78587775fa62418b51a052dfa8efc919': {'title': 'Blikk (trykt utg.). 2001 Nr. 10',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981108_001',
#   'year': '2001',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '14f981bd4a4f457cdffa34a0f807ca88': {'title': 'Blikk (trykt utg.). 1995 Nr. 6',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181052_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '269f67eb484804c36ebd62fe71363264': {'title': 'Blikk (trykt utg.). 2012 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481176_001',
#   'year': '2012',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '03e082a037e143180bc88e04ff56defb': {'title': 'Blikk (trykt utg.). 2014 Nr. 9',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481224_001',
#   'year': '2014',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '50893445d4474ed7a3a516bc8c1bbe31': {'title': 'Blikk (trykt utg.). 2015 Nr. 1',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481216_001',
#   'year': '2015',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '14cd3cc039c0867a5ec5394157984659': {'title': 'Blikk (trykt utg.). 2014 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481134_001',
#   'year': '2014',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '6909e476009ee2edd8b7907c5a7466cb': {'title': 'Blikk (trykt utg.). 1996 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181062_001',
#   'year': '1996',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'fc78c381bf53870413a3d7c9d3d1c125': {'title': 'Blikk (trykt utg.). 2001 Nr. 4',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091981131_001',
#   'year': '2001',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '25241efdd9fb5770a669cacd437f2611': {'title': 'Blikk (trykt utg.). 2008 Nr. 8',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981044_001',
#   'year': '2008',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '9f853d7232f0571abb1b619339ead318': {'title': 'Blikk (trykt utg.). 2011 Nr. 4',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481140_001',
#   'year': '2011',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '15f5db145093542c3246b3f14e157a42': {'title': 'Blikk (trykt utg.). 2009 Nr. 12',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981028_001',
#   'year': '2009',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '60795c165fa82be1f2bcf304a1477774': {'title': 'Blikk (trykt utg.). 1995 Nr. 8',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181054_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '1659ef4d9c01ecdb1f554ea5e0026000': {'title': 'Blikk (trykt utg.). 2006 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981050_001',
#   'year': '2006',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'b77f762eecec109913d5c781130ff230': {'title': 'Blikk (trykt utg.). 1995 Nr. 9',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181055_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '2e30b98942f3522adfaec857fc06d2ad': {'title': 'Blikk (trykt utg.). 2005 Nr. 4',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981010_001',
#   'year': '2005',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '07affc1f2424e8c863eb511229e862dc': {'title': 'Blikk (trykt utg.). 2004 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981066_001',
#   'year': '2004',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '76e2216e9db9116ba78cf0ffa791ce82': {'title': 'Blikk (trykt utg.). 2006 Nr. 11',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481250_001',
#   'year': '2006',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'f3c5788525925cfabeb9f13c1343e6a2': {'title': 'Blikk (trykt utg.). 2013 Nr. 11',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481112_001',
#   'year': '2013',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'e75be1097ffe55c34900af3e3c552636': {'title': 'Blikk (trykt utg.). 2013 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481232_001',
#   'year': '2013',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '53cec5363cead3fd265a7b34c9aff92d': {'title': 'Blikk (trykt utg.). 2005 Nr. 7',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981014_001',
#   'year': '2005',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'f12a4f2618a237941fb063b6c32d786f': {'title': 'Blikk (trykt utg.). 1994 Nr. 10',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181089_001',
#   'year': '1994',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '258575531f189221800d17e098d181ee': {'title': 'Blikk (trykt utg.). 1991 Nr. 9',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181133_001',
#   'year': '1991',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'e4795f9ec7dbb07305505c577af1f7b6': {'title': 'Blikk (trykt utg.). 1998 Nr. 6',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181111_001',
#   'year': '1998',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'f11824a7f92892239a728474addf0332': {'title': 'Blikk (trykt utg.). 1999 Nr. 12',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181104_001',
#   'year': '1999',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '6ae3b7936abefa80189443b5db9410ad': {'title': 'Blikk (trykt utg.). 1995 Nr. 11',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181057_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '0b4e3366bc437a298221a6d0bd45f858': {'title': 'Blikk (trykt utg.). 1993 Nr. 5',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181025_001',
#   'year': '1993',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '7e0899a02436962bf799f7a8da7ee40d': {'title': 'Blikk (trykt utg.). 1991 Nr. 11',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181135_001',
#   'year': '1991',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '2d9d04d12c33da546d53fea665b558c9': {'title': 'Blikk (trykt utg.). 2003 Nr. 9',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981086_001',
#   'year': '2003',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '85b1557862edbd12ff3fbb65f96d3dd4': {'title': 'Blikk (trykt utg.). 2009 Nr. 4',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981040_001',
#   'year': '2009',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'd397f26a06b45bd2daade58a0ff6ece5': {'title': 'Blikk (trykt utg.). 2008 Nr. 6/7',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481152_001',
#   'year': '2008',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '5dfce01e9aa1b78cf6dcfdd6ffae1025': {'title': 'Blikk (trykt utg.). 2005 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981008_001',
#   'year': '2005',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '3875b94d2decad177de00d9931db2c34': {'title': 'Blikk (trykt utg.). 1994 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181082_001',
#   'year': '1994',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '7f7f0973c15c73df06a759eb586e02f5': {'title': 'Blikk (trykt utg.). 1998 Nr. 12',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181125_001',
#   'year': '1998',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '26bc703b7d5fa6df5b83ffadb9fd7cbd': {'title': 'Blikk (trykt utg.). 1995 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181048_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '1f4a92540c70caf1ec417ba180d06d1e': {'title': 'Blikk (trykt utg.). 2001 Nr. 1',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091981129_001',
#   'year': '2001',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '21dcd35fa00905adb10345867e3b3390': {'title': 'Blikk (trykt utg.). 1994 Nr. 11',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181090_001',
#   'year': '1994',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '92974e9867272f491e32d6b9c5496c79': {'title': 'Blikk (trykt utg.). 2014 Nr. 8',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481202_001',
#   'year': '2014',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '17a5db68a647795cfcc906df1ad578a7': {'title': 'Blikk (trykt utg.). 1992 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181036_001',
#   'year': '1992',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'fc7808e567196ddded9f28786adfc478': {'title': 'Blikk (trykt utg.). 2013 Nr. 8',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481222_001',
#   'year': '2013',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '72fb5863b42b3b7c83d6ba28ec1d947b': {'title': 'Blikk (trykt utg.). 2006 Nr. 4',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981052_001',
#   'year': '2006',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '0cf5eb39a5dd8ddbf647d651c4a8a50c': {'title': 'Blikk (trykt utg.). 1993 Nr. 12',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181032_001',
#   'year': '1993',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'ec0ec73d6d0c9af27e00eb3a43efa095': {'title': 'Blikk (trykt utg.). 2011 Nr. 2',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481126_001',
#   'year': '2011',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  'ef0f20cc8ea97ff40d55c89a794e1639': {'title': 'Blikk (trykt utg.). 1995 Nr. 3',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181049_001',
#   'year': '1995',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '60662feae0110c7c0f011c1791331c66': {'title': 'Blikk (trykt utg.). 2004 Nr. 9',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019120981078_001',
#   'year': '2004',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '42ac841f38bb2bd958754e2c9601641f': {'title': 'Blikk (trykt utg.). 1991 Nr. 10',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019091181134_001',
#   'year': '1991',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []},
#  '0e50280bc05d27aca605f1e9718a81b7': {'title': 'Blikk (trykt utg.). 2008 Nr. 5',
#   'contr': [],
#   'pages': [],
#   'urn': 'URN:NBN:no-nb_digitidsskrift_2019100481164_001',
#   'year': '2008',
#   'topics': ['homoseksualitet', 'homofili', 'tidsskrifter'],
#   'genres': ['periodical'],
#   'target_group': []}}

# %%
konk = pd.DataFrame(get_konkordanser('vi', urns = rand, window = 500))

# %%
konks = lambda x: pd.DataFrame(get_konkordanser(x, urns = rand, window = 500))

# %%
konk
# Out:
#                                    urn  \
# 0     274c194c0670b84625233d15dbc2a204
# 1     274c194c0670b84625233d15dbc2a204
# 2     274c194c0670b84625233d15dbc2a204
# 3     274c194c0670b84625233d15dbc2a204
# 4     274c194c0670b84625233d15dbc2a204
# ...                                ...
# 6228  15978476302695a4b857b76456d7945b
# 6229  15978476302695a4b857b76456d7945b
# 6230  15978476302695a4b857b76456d7945b
# 6231  15978476302695a4b857b76456d7945b
# 6232  15978476302695a4b857b76456d7945b
#
#                                                                                                      before  \
# 0      ungdom er ei ekstra sårbar gruppe: «[...] de lurer på mange hjerteskjærende ting. For eksempel fikk
# 1                                                                                    som tenker helhetlig.
# 2     Skeiv verden og Skeiv ungdom skal utradere skammen og mobbingen alene, er uansvarlig av regjeringen.
# 3       år siden homoforbudet i straffelo- flere radiohits bak seg. ven ble opphevet. Med oss på laget har
# 4     Morten Skogmus og Klatremus er som kjent venner. - Forholdet deres er ikke helt definert, men åpent.
# ...                                                                                                     ...
# 6228               sier han. gg " Hamlet, trommer B .< Morsomt seg til en hybrid av funk, jazz-ele- Så far
# 6229                 Sugarpops at det var mortydelig satte pris på. - Det var et somt å spille på Castro. -
# 6230            en i dykker- re fra Amsterdam og Berlin ker til at våre deiligste og Store under- drakt og
# 6231          nnom uten synlig kles- Oslo som for tida definitivt og pusset opp huset med bar utsida møtte
# 6232            tenke pa varme, sol og sjø. Hva skyldes sa denne trang- en til å lage rolig harmonisk lyd?
#
#      word  \
# 0      vi
# 1      Vi
# 2      Vi
# 3      vi
# 4      Vi
# ...   ...
# 6228   vi
# 6229   Vi
# 6230   vi
# 6231   vi
# 6232   Vi
#
#                                                                                                              after
# 0                   spørsmålet ‘hvordan kan jeg stoppe å være homofil?’ Mange skulle ønske at de var noe annet enn
# 1                                                  trenger trojanske hester som løfter lhbt-temaet inn på arenaer
# 2                 forventer at de rødgrønne nå lager en konkret og helhetlig lhbt-plan der tiltakene i skolen blir
# 3              fått Mer sang blir det når Norges lekreste homseden største homoforkjemperen i Norge, Kim Fri- kor,
# 4                        får ikke vite om deres sivile status, og det kan man bruke til sin egen fordel. Klatremus
# ...                                                                                                            ...
# 6228   håpe Sugarpops-budskapet menter og jungle, alt innpakket i nådde fram til homsene. I hvertfall 90-tallslyd,
# 6229                  kjengodt publikum, sier Malika, grup- ner mange i miljøet så det er vår .yl|| .|B pas eneste
# 6230     så også en kjekk - helt til du spaserer ut i skitneste fantasier kan leves holdninasiiODO- sikkerhetsvakt
# 6231                    en fyr som ode, er det alltid mye gir en følelse av å være iet nede, skikkelig pisserenne,
# 6232          Sugairpops spør gitarist og låtskriver Glenn Glenn Thomassen, gitar Thomassen. - Jeg har lav puls av
#
# [6233 rows x 4 columns]

# %% [markdown]
# ### For kollokasjoner, lag en referanse

# %%
ref = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# ### Hent en kollokasjon
#
# Kollokasjonene tar utgangspunkt i en konkordans. Parametre er før og etter

# %%
coll = count_from_conc_window(konk, before = 5, after = 5)

# %%
def make_coll(word, urns, before = 5, after = 5, ref = ref):
    konk = pd.DataFrame(get_konkordanser(word, urns = urns, window = 500))
    coll = count_from_conc_window(konk, before = 5, after = 5)
    coll['pmi'] = coll[0]/ref.tot
    return nb.frame_sort(coll, 'pmi')

# %% [markdown]
# ### lager en vektingskolonne
#
# Kolonne kalt `pmi` for  pointwise mutual information.
#
# $\textrm{pmi} = \frac{\textrm{collocation frequencies}}{\textrm{reference frequencies}}$

# %%
coll['pmi'] = coll[0]/ref.tot

# %%
nb.frame_sort(coll, 'pmi').head(50)
# Out:
#                 0       pmi
# lesbiske       43  0.001595
# VW             33  0.001386
# Fjeldstad      29  0.001279
# S2             30  0.001060
# EE             38  0.000952
# gratulerer     23  0.000941
# homofile       54  0.000901
# homofil        21  0.000900
# Pf             29  0.000896
# samboende      15  0.000632
# vikar          33  0.000628
# Miami          19  0.000586
# 19.00          13  0.000578
# legning        28  0.000569
# forespørsler   17  0.000515
# HP             28  0.000508
# Castro         14  0.000504
# Space          18  0.000485
# BH             22  0.000456
# homoseksuelle  13  0.000446
# Telefax        26  0.000433
# Haraldsen      12  0.000404
# spe            28  0.000399
# mva.           20  0.000380
# etterfølger    24  0.000368
# Lover          28  0.000356
# P.             13  0.000343
# ildce           8  0.000340
# sam-           28  0.000337
# O.             12  0.000337
# Folke-         26  0.000329
# ▼              15  0.000323
# Sak            31  0.000302
# ee             19  0.000290
# NORGE          32  0.000289
# innby           7  0.000288
# Fish           22  0.000287
# OSS            11  0.000285
# bekreftet      86  0.000282
# Karina          7  0.000279
# utfordre       20  0.000279
# Kjersti        30  0.000275
# lovar           6  0.000274
# avslører       21  0.000266
# permisjon      34  0.000266
# utløper         7  0.000261
# mnd            14  0.000258
# slappet        19  0.000252
# Apen           11  0.000252
# ode            14  0.000251

# %%
coll.sum()
# Out:
# 0    57164
# dtype: int64

# %%
make_coll('homse', rand).head(20)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# OSError: [WinError 10051] Det ble forsøkt en kontaktoperasjon til et nettverk som ikke kunne nås
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', OSError(10051, 'Det ble forsøkt en kontaktoperasjon til et nettverk som ikke kunne nås', None, 10051, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-97-b0ec5905db4a> in <module>
# ----> 1 make_coll('homse', rand).head(20)
#
# <ipython-input-41-38ffdf5fbf0b> in make_coll(word, urns, before, after, ref)
#       1 def make_coll(word, urns, before = 5, after = 5, ref = ref):
# ----> 2     konk = pd.DataFrame(get_konkordanser(word, urns = urns, window = 500))
#       3     coll = count_from_conc_window(konk, before = 5, after = 5)
#       4     coll['pmi'] = coll[0]/ref.tot
#       5     return nb.frame_sort(coll, 'pmi')
#
# <ipython-input-4-ca43c8e96249> in get_konkordanser(word, urns, window, n)
#     182     konks = []
#     183     for u in urns:
# --> 184         konks += get_konks(u, word, window = window, n = n)
#     185     return konks
#
# <ipython-input-4-ca43c8e96249> in get_konks(urn, phrase, window, n)
#     162
#     163     }
# --> 164     r = requests.get("https://api.nb.no/catalog/v1/items/{urn}/contentfragments".format(urn=urn), params = query)
#     165     res = r.json()
#     166     results = []
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError(10051, 'Det ble forsøkt en kontaktoperasjon til et nettverk som ikke kunne nås', None, 10051, None))

# %%
make_coll('dem', rand).head(20)
# Out:
#                 0       pmi
# eda            16  0.000432
# send           48  0.000350
# nålene          8  0.000349
# lesbiske        9  0.000334
# Folke-         26  0.000329
# Send           19  0.000219
# homofile       13  0.000217
# ågi            14  0.000180
# stjeler         8  0.000142
# lovet          59  0.000111
# beskytte       47  0.000099
# klemmer         8  0.000092
# vanker          2  0.000089
# homofil         2  0.000086
# høylydt         2  0.000075
# artister        2  0.000071
# Il             22  0.000070
# nummer         46  0.000070
# ringe          59  0.000070
# homoseksuelle   2  0.000069

# %%
make_coll('lyst', rand).head(20)
# Out:
#                   0       pmi
# Mimi             14  0.000496
# kvinnelig        21  0.000115
# lesbiske          3  0.000111
# kloden            4  0.000053
# morsomste         1  0.000043
# homofil           1  0.000043
# diskriminerende   1  0.000043
# dent              1  0.000043
# bankkonto         1  0.000042
# glitter           1  0.000042
# Akerselva         1  0.000040
# intervjuede       1  0.000039
# innmari           1  0.000039
# provosert         1  0.000039
# høstens           1  0.000039
# overbringe        1  0.000038
# stresset          2  0.000038
# oppfatningene     1  0.000034
# HUN               1  0.000033
# abonnement        1  0.000032

# %%
make_coll('penger', rand).head(20)
# Out:
#                   0       pmi
# Fo               28  0.000698
# 18.00             5  0.000159
# dj                6  0.000126
# hiv               3  0.000091
# 2.500             1  0.000045
# investerte        1  0.000044
# oppfordringen     1  0.000044
# Records           1  0.000041
# finansierer       1  0.000041
# Workshop          1  0.000038
# lesbiske          1  0.000037
# tolerant          1  0.000037
# Vegas             1  0.000036
# bevilget          5  0.000036
# Alicia            1  0.000033
# ente              1  0.000033
# kassa             2  0.000033
# sommerens         1  0.000032
# bevilges          1  0.000031
# besteforeldrene   1  0.000031

# %%
make_coll('aids', rand).head(20)
# Out:
#                    0       pmi
# lesbiske         112  0.004154
# hiv              127  0.003847
# informerer        82  0.003003
# STATENS           81  0.002896
# homofile         113  0.001885
# Landsforeningen   22  0.000865
# HELSE             20  0.000848
# Opera             28  0.000500
# Aires             17  0.000433
# forsvinn          11  0.000426
# Seksjon           22  0.000422
# sjenert           45  0.000406
# ▼                 17  0.000366
# MM                46  0.000330
# lig              112  0.000319
# Pluss              8  0.000288
# Verdens           86  0.000271
# 1604               8  0.000255
# Mill              33  0.000235
# råka              11  0.000212

# %%
make_coll('hiv', rand).head(20)
# Out:
#               0       pmi
# aids        129  0.003722
# adopsjon    121  0.002617
# fei         121  0.001494
# HELSE        31  0.001315
# sammen-      22  0.000949
# Gratis       16  0.000712
# smitter      20  0.000686
# ds          121  0.000662
# Pluss        18  0.000647
# Rica         17  0.000594
# Oppfølging   21  0.000577
# JW           10  0.000430
# ▼            19  0.000409
# gratis      120  0.000391
# forelegge    11  0.000375
# Pb           26  0.000323
# Costa        17  0.000319
# sere         10  0.000299
# gere          9  0.000289
# Hirsch        9  0.000287
